# %%
# !pip install diffusers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.3 MB/s eta 0:00:00
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# safety_checker/config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# ...

# %%
# !mkdir /content/new_folder

# %%
import os

# 폴더 생성 (이미 존재하는 경우에는 생성하지 않음)
folder_path = '/content/new_folder'
os.makedirs(folder_path, exist_ok=True)

for i in range(100):
    prompt = "slip-and-fall-accident"
    image = pipe(prompt).images[0]

    # 이미지 파일 경로를 설정 (예: /content/new_folder/acc_1.jpg)
    filename = f"{folder_path}/acc_{i+1}.jpg"
    image.save(filename)
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# slip-and-fall-accident

# %%
# !zip -r /content/new_folder.zip /content/new_folder
# Out:
#   adding: content/new_folder/ (stored 0%)
#   adding: content/new_folder/acc_69.jpg (deflated 0%)
#   adding: content/new_folder/acc_70.jpg (deflated 1%)
#   adding: content/new_folder/acc_7.jpg (deflated 0%)
#   adding: content/new_folder/acc_19.jpg (deflated 0%)
#   adding: content/new_folder/acc_48.jpg (deflated 0%)
#   adding: content/new_folder/acc_9.jpg (deflated 0%)
#   adding: content/new_folder/acc_75.jpg (deflated 0%)
#   adding: content/new_folder/acc_32.jpg (deflated 0%)
#   adding: content/new_folder/acc_64.jpg (deflated 0%)
#   adding: content/new_folder/acc_86.jpg (deflated 0%)
#   adding: content/new_folder/acc_31.jpg (deflated 0%)
#   adding: content/new_folder/acc_47.jpg (deflated 1%)
#   adding: content/new_folder/acc_67.jpg (deflated 0%)
#   adding: content/new_folder/acc_41.jpg (deflated 0%)
#   adding: content/new_folder/acc_11.jpg (deflated 0%)
#   adding: content/new_folder/acc_28.jpg (deflated 0%)
#   adding: content/new_folder/acc_20.jpg (deflated 0%)
# ...
