# %%
# !pip install Augmentor
import Augmentor
from google.colab import drive
drive.mount('/content/drive')
from PIL import Image, ImageEnhance, ImageChops
import numpy as np
import random

import Augmentor

path_to_data = "/content/drive/MyDrive/data1/"

# Create a pipeline
img = Augmentor.Pipeline(path_to_data)

## 좌우 반전
img.flip_left_right(probability=1.0) 

## 상하 반전
img.flip_top_bottom(probability=1.0)

## 왜곡
img.random_distortion(probability=1, grid_width=10, grid_height=10, magnitude=8)

## 증강 이미지 수
img.sample(10)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import Augmentor

# %%
from PIL import Image, ImageEnhance, ImageChops
import numpy as np
import random

# %%
import Augmentor

path_to_data = "/content/drive/MyDrive/data1/"

# Create a pipeline
img = Augmentor.Pipeline(path_to_data)
# Out:
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/data1/output.

# %%
## 좌우 반전
img.flip_left_right(probability=1.0) 

## 상하 반전
img.flip_top_bottom(probability=1.0)

## 왜곡
img.random_distortion(probability=1, grid_width=10, grid_height=10, magnitude=8)

## 증강 이미지 수
img.sample(10)
# Out:
# Processing <PIL.Image.Image image mode=RGB size=599x832 at 0x7F799EF35CA0>: 100%|██████████| 10/10 [00:00<00:00, 13.09 Samples/s]
